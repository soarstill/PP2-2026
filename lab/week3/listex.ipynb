# %% [markdown]
# ## List 연습 노트 파일입니다.

# %% [markdown]
# 리스트의 합병 연산 (+)
# 리스트의 곱 연산 (*)

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
fruit1 = ["사과","바나나"]
fruit2 = ["복숭아", "포도"]
print(fruit1)
# Out:
# ['사과', '바나나']
