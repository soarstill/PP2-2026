# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv("shopping.csv")
df["Revenue"] = df["UnitPrice"] * df["Quantity"]

# %%
df.groupby("Category")["Revenue"].sum()
# Out:
# Category
# Beauty          780900.0
# Electronics    2332200.0
# Fashion        1170000.0
# Home           1169300.0
# Sports         1156300.0
# Name: Revenue, dtype: float64

# %%
df.groupby("Category")["Revenue"].agg(["sum", "mean", "count"])
# Out:
#                    sum          mean  count
# Category
# Beauty        780900.0  55778.571429     14
# Electronics  2332200.0  80420.689655     29
# Fashion      1170000.0  78000.000000     15
# Home         1169300.0  55680.952381     21
# Sports       1156300.0  60857.894737     19

# %%
df.groupby("Category")["UnitPrice"].mean()
# Out:
# Category
# Beauty         39785.714286
# Electronics    41844.827586
# Fashion        41446.666667
# Home           33728.571429
# Sports         34315.789474
# Name: UnitPrice, dtype: float64
